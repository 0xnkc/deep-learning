# %% [markdown]
# #**HW 3: Convolutional Neural Networks**
#
# In this homework, we will explore how to develop a simple Convolutional Neural Network for image classification. We will use the Fashion Minst dataset. In the first part, we will learn how to develop a simple CNN, while in the second part we will explore the impact of various hyper-parameters in the learning performances.

# %% [markdown]
# ##Exercise 3.1: Simple CNN
#
# Let's start by importing Tensorflow, Keras and Numpy

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

# %% [markdown]
# ###Load dataset:
# ### Load Data: Fashion MNIST dataset
#
# We will use the Fashion MNIST dataset, a dataset of Zalando's articles. Each sample is a 28x28 pixels grayscale image, associated with a label from 10 classes:
#
# class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
#
# Each pixel intensity is represented by a uint8 (byte) from 0 to 255.
# We will divide the dataset in training, validation and test set. As you already know, the training set will be used to train the model, the validation set will be used to perform model selection and finally, the test set will be used to asses the performance of the deep network.
#
# Since we will use a [2DConv](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) we have to provide also a new dimension of the input that represents the number of channels (that in grey scale image is just one). Therefore we use [tf.expand_dims](https://www.tensorflow.org/api_docs/python/tf/expand_dims) to transform each image from a matrix to a 3-dimensional tensor. Finaly we have to normalize the input data.

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = (
    fashion_mnist.load_data()) #The dataset is already divede in test and training..

#We extract the first 5000 samples of the training set, to use them as the validation set
X_valid, X_train = X_train_full[:5000], X_train_full[5000:] 
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %% [markdown]
# Let's take a look at a sample of the images in the dataset:

# %%
n_rows = 5
n_cols = 10
plt.figure(figsize=(n_cols*1.4, n_rows * 1.6))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]])
plt.show()

# %% [markdown]
# ### [TO COMPLETE] Input Normalization:
#
# When using Gradient Descent, it is usually a good idea to ensure that all the features have a similar scale. Try to standardize the pixel values.

# %%
#[TO COMPLETE]: define X_train_scaled, X_valid_scaled and X_test_scaled, the sets that contains 
#Hint: For each feature (pixel intensity), you must subtract the mean() of that 
#feature (across all instances, so use axis=0) and divide by its standard 
#deviation (std(), again axis=0)


X_train = (X_train - np.mean(X_train,axis=0)) / np.std(X_train,axis=0)
X_valid = (X_valid - np.mean(X_valid,axis=0)) / np.std(X_valid,axis=0)
X_test = (X_test - np.mean(X_test,axis=0)) / np.std(X_test,axis=0)


#Add one dimension to manage the channel
X_train=tf.expand_dims(X_train, 3) 
X_valid=tf.expand_dims(X_valid, 3) 
X_test=tf.expand_dims(X_test,3)

#Make sure you compute the means and standard deviations on the training set,
#and use these statistics to scale the training set, the validation set and the
# test set

# %% [markdown]
# ###Define the model
#
# Let's create a simple CNN. The model will be composed of:
# * One 2D convolutional layer with kernel size 3x3 and 32 output filters/features, that use ReLu activation function
# * a Max Pooling layer (2D) of size 2x2 ([MaxPool2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D))
# * a Flatten layer
# * a final Dense layer with 10 output neurons (one per class), and with the "softmax" activation function to ensure that the sum of all the estimated class probabilities for each image is equal to 1.
# Note that as 'input_shape' attribute's value in the first layer report also the third dimension that represents the channel.

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(filters=32, kernel_size=[3,3], padding="same", activation="relu", input_shape=[28, 28,1]),
    keras.layers.MaxPool2D(pool_size=[2,2]),
    keras.layers.Flatten(),
    keras.layers.Dense(10, activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy",
              optimizer='sgd',
              metrics=["accuracy"])

# %% [markdown]
# Print the model summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                62730
# =================================================================
# Total params: 63,050
# Trainable params: 63,050
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Note that the number of parameters mostly depends on the output layers, indeed the parameter sharing techinique used by the 2D convolutional layers allows to significantly reduce the number of learnable weights.
# Now we can train the model.

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=128,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 430/430 [==============================] - 24s 55ms/step - loss: 1.0109 - accuracy: 0.6820 - val_loss: 0.5194 - val_accuracy: 0.8262
# Epoch 2/10
# 430/430 [==============================] - 23s 53ms/step - loss: 0.4986 - accuracy: 0.8280 - val_loss: 0.4483 - val_accuracy: 0.8508
# Epoch 3/10
# 430/430 [==============================] - 23s 53ms/step - loss: 0.4379 - accuracy: 0.8510 - val_loss: 0.4145 - val_accuracy: 0.8582
# Epoch 4/10
# 430/430 [==============================] - 23s 54ms/step - loss: 0.4114 - accuracy: 0.8586 - val_loss: 0.4079 - val_accuracy: 0.8658
# Epoch 5/10
# 430/430 [==============================] - 23s 54ms/step - loss: 0.3861 - accuracy: 0.8664 - val_loss: 0.3952 - val_accuracy: 0.8700
# Epoch 6/10
# 430/430 [==============================] - 23s 54ms/step - loss: 0.3745 - accuracy: 0.8704 - val_loss: 0.3994 - val_accuracy: 0.8658
# Epoch 7/10
# 430/430 [==============================] - 23s 54ms/step - loss: 0.3575 - accuracy: 0.8767 - val_loss: 0.3862 - val_accuracy: 0.8666
# Epoch 8/10
# 430/430 [==============================] - 23s 54ms/step - loss: 0.3497 - accuracy: 0.8771 - val_loss: 0.3549 - val_accuracy: 0.8810
# Epoch 9/10
# 430/430 [==============================] - 23s 54ms/step - loss: 0.3403 - accuracy: 0.8805 - val_loss: 0.3446 - val_accuracy: 0.8826
# Epoch 10/10
# 430/430 [==============================] - 24s 55ms/step - loss: 0.3310 - accuracy: 0.8844 - val_loss: 0.3463 - val_accuracy: 0.8830

# %% [markdown]
# Plot the loss and the accuracy trends for the training and validation set. Then, compute the result on the test set.

# %%
def plot_loss(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['loss'])
  plt.plot(history.epoch,history.history['val_loss'])
  plt.title('loss')

def plot_accuracy(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['accuracy'])
  plt.plot(history.epoch,history.history['val_accuracy'])
  plt.title('accuracy')

plot_loss(history)

plot_accuracy(history)

scores = model.evaluate(X_test, y_test, verbose=2)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 313/313 - 2s - loss: 0.3681 - accuracy: 0.8723
# accuracy: 87.23%

# %% [markdown]
# ###Visualize Weights
#
# An interesting thing to do is to visualize the learned weights for the convolutional layer. We have 32 kernels of size 3x3, we can just plot them as images, mapping the weight values to grayscale.

# %%
# Weights for the first convolutional layer
w0=model.get_weights()[0][:,:,0,:]

# Normalize to range 0.0 - 1.0
w0-=np.min(w0)
w0/=np.max(w0)

for r in range(4):
    for c in range(8):
        n=r*8+c
        plt.subplot(4, 8, n+1)
        plt.imshow(w0[:,:,n], interpolation='none')
        plt.axis('off')
        plt.gray()
plt.show()

# %% [markdown]
# They might be a bit hard to interpret, but it seems that the various filters have learned to detect various corners and edges.

# %% [markdown]
# ### [TO COMPLETE] Deep CNN
# Let's consider a deeper model, more precily in this exercise we consider a model composed of:
# * One 2D convolutional layer with kernel size 3x3 and 32 output filters/features, that use ReLu activation function
# * a Max Pooling layer (2D) of size 2x2
# * One 2D convolutional layer with kernel size 2x2 and 16 output filters/features, that use ReLu activation function
# * a Max Pooling layer (2D) of size 2x2
# * a Flatten layer
# * a final Dense layer with 10 output neurons (one per class), and with the "softmax" activation function

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(filters=32, kernel_size=[3,3], activation='relu', input_shape=[28, 28,1]),
    keras.layers.MaxPool2D(pool_size=[2,2]),
    keras.layers.Conv2D(filters=16, kernel_size=[2,2], activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(10, activation="softmax")
  ])
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])
  
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 16)        2064
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5770
# =================================================================
# Total params: 8,154
# Trainable params: 8,154
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# [TO COMPLETE] Explain in this cell:
#
# 1.   how the number of parameters on each of the two Conv2D layers is determined;
#
# 2.   the reasons why the two considered convolutional layers have a different number of parameters.
#
# Answers:
#
#
# 1.   Answer to question 1
#
#     The Conv2D is performed with the 2 axes x and y.  in general, given 𝑀 filters of shape 𝐾×𝐾 and input of shape 𝐻×𝑊×𝐷, then the number of parameters of the standard 2d convolutional layer, with scalar biases, is 𝑀∗(𝐾∗𝐾∗𝐷)+𝑀 and, without biases, is 𝑀∗(𝐾∗𝐾∗𝐷).
# Example: 5*5*3*100 = 7500 and the bias is 100 Total=7600.
#
#
# 2.  Answer to question 2
#
#     The parameters are different because of
# the Number of hidden layers,
# the Number of convolutional layers,
# the number of nodes per hidden layer,
# max pooling window size.

# %% [markdown]
# Let's now train our deep CNN.

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=128,
                  validation_data=(X_valid, y_valid))

plot_loss(history)
plot_accuracy(history)

scores = model.evaluate(X_test, y_test, verbose=2)
print(" %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print("----------------------------")
# Out:
# Epoch 1/10
# 430/430 [==============================] - 26s 59ms/step - loss: 1.5612 - accuracy: 0.4631 - val_loss: 0.6634 - val_accuracy: 0.7606
# Epoch 2/10
# 430/430 [==============================] - 25s 59ms/step - loss: 0.6564 - accuracy: 0.7670 - val_loss: 0.5744 - val_accuracy: 0.7764
# Epoch 3/10
# 430/430 [==============================] - 26s 59ms/step - loss: 0.5509 - accuracy: 0.8025 - val_loss: 0.4905 - val_accuracy: 0.8256
# Epoch 4/10
# 430/430 [==============================] - 25s 59ms/step - loss: 0.5016 - accuracy: 0.8224 - val_loss: 0.4814 - val_accuracy: 0.8272
# Epoch 5/10
# 430/430 [==============================] - 25s 59ms/step - loss: 0.4734 - accuracy: 0.8336 - val_loss: 0.4420 - val_accuracy: 0.8464
# Epoch 6/10
# 430/430 [==============================] - 25s 59ms/step - loss: 0.4516 - accuracy: 0.8405 - val_loss: 0.4204 - val_accuracy: 0.8556
# Epoch 7/10
# 430/430 [==============================] - 25s 59ms/step - loss: 0.4282 - accuracy: 0.8490 - val_loss: 0.4128 - val_accuracy: 0.8614
# Epoch 8/10
# 430/430 [==============================] - 25s 59ms/step - loss: 0.4213 - accuracy: 0.8513 - val_loss: 0.4155 - val_accuracy: 0.8560
# Epoch 9/10
# 430/430 [==============================] - 25s 59ms/step - loss: 0.4095 - accuracy: 0.8536 - val_loss: 0.3907 - val_accuracy: 0.8690
# Epoch 10/10
# 430/430 [==============================] - 25s 59ms/step - loss: 0.3885 - accuracy: 0.8643 - val_loss: 0.4030 - val_accuracy: 0.8606
# 313/313 - 2s - loss: 0.4228 - accuracy: 0.8502
#  accuracy: 85.02%
# ----------------------------

# %% [markdown]
# ## [TO COMPLETE] Exercise 3.2: Develop a better CNN
# Let's develop a network that performs better than the very simple one above. This exercise aims to explore how much the various hyper-parameters influence the classification capability of the model.
#
# **[TO COMPLETE]**: Your task is to modify some of the hyper-parameters of the previous exercise's network and compare the results. At least one of the models you try should have an improvement in the test set results (generalization) over the result of the model used in the previous exercise.
# In the cell below report only the code of the **best model** that you can find. In addtion, print out its result on the test set, and plot the accuracy and the loss trends in the notebook you return.
# Moreover, for each setup you test, analyze and discuss the obtained results briefly in the last cells at the bottom.
#
# Hint: Each reparameterization should change a different aspect in the network, while the rest of the parameters would stay the same.
# Example parameters to try to change (we suggest to test at least one re-parametrization for each of these categories):
#
# *    number of layers or neurons or filters dimension
# *   activation functions
# *   epochs
# *   batch sizes
# *   optimizer, see TensorFlow documentation on [optimizers](https://https://www.tensorflow.org/api_docs/python/tf/keras/optimizers)
# *   max-pooling on/off on certain layers, or pool size
#
# For what concerns the optimizer, as you can see in the 'compile' method [documentation](https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile) is it possible to pass as 'optimizer ' attribute's value a string (the name of optimizer) or an optimizer instance.
#
# Notice that changing the final layer's softmax activation plus the categorical_crossentropy loss requires some consideration. Don't do it unless you have a good plan.

# %%
from tensorflow.keras.optimizers import SGD


model = keras.models.Sequential([
    keras.layers.Conv2D(filters=32, kernel_size=[3,3], activation='relu', input_shape=[28, 28,1]),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=32, kernel_size=[3,3], activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=[2,2]),
    keras.layers.Dropout(0.25),
    
    keras.layers.Conv2D(filters=64, kernel_size=[3,3], activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=64, kernel_size=[3,3], activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=[2,2]),
    keras.layers.Dropout(0.25),
    

    keras.layers.Flatten(),
    keras.layers.Dense(512, activation="relu"),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),

    keras.layers.Dense(10, activation="softmax")

  ])
# NUM_EPOCHS = 25
# INIT_LR = 1e-2
# BS = 32
# opt = SGD(lr=INIT_LR, momentum=0.9, decay=INIT_LR / NUM_EPOCHS)

model.compile(loss="sparse_categorical_crossentropy",optimizer="sgd",metrics=["accuracy"])
  
print(model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 26, 26, 32)        128
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 24, 24, 32)        9248
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 24, 24, 32)        128
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 10, 10, 64)        18496
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 10, 10, 64)        256
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 597,738
# Trainable params: 596,330
# Non-trainable params: 1,408
# _________________________________________________________________
# None

# %%
history = model.fit(X_train, y_train, epochs=25, batch_size=32,validation_data=(X_valid, y_valid))

plot_loss(history)
plot_accuracy(history)

scores = model.evaluate(X_test, y_test, verbose=2)
print(" %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print("----------------------------")
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 155s 90ms/step - loss: 0.9505 - accuracy: 0.6904 - val_loss: 0.3707 - val_accuracy: 0.8692
# Epoch 2/25
# 1719/1719 [==============================] - 153s 89ms/step - loss: 0.4958 - accuracy: 0.8212 - val_loss: 0.3201 - val_accuracy: 0.8846
# Epoch 3/25
# 1719/1719 [==============================] - 154s 89ms/step - loss: 0.4206 - accuracy: 0.8507 - val_loss: 0.2953 - val_accuracy: 0.8914
# Epoch 4/25
# 1719/1719 [==============================] - 153s 89ms/step - loss: 0.3852 - accuracy: 0.8621 - val_loss: 0.2792 - val_accuracy: 0.8978
# Epoch 5/25
# 1719/1719 [==============================] - 154s 90ms/step - loss: 0.3558 - accuracy: 0.8722 - val_loss: 0.2646 - val_accuracy: 0.9024
# Epoch 6/25
# 1719/1719 [==============================] - 154s 90ms/step - loss: 0.3339 - accuracy: 0.8783 - val_loss: 0.2609 - val_accuracy: 0.9030
# Epoch 7/25
# 1719/1719 [==============================] - 154s 90ms/step - loss: 0.3305 - accuracy: 0.8819 - val_loss: 0.2474 - val_accuracy: 0.9100
# Epoch 8/25
# 1719/1719 [==============================] - 155s 90ms/step - loss: 0.3125 - accuracy: 0.8869 - val_loss: 0.2438 - val_accuracy: 0.9078
# Epoch 9/25
# 1719/1719 [==============================] - 154s 90ms/step - loss: 0.3077 - accuracy: 0.8888 - val_loss: 0.2420 - val_accuracy: 0.9076
# Epoch 10/25
# 1719/1719 [==============================] - 154s 89ms/step - loss: 0.2950 - accuracy: 0.8913 - val_loss: 0.2356 - val_accuracy: 0.9124
# Epoch 11/25
# 1719/1719 [==============================] - 154s 90ms/step - loss: 0.2885 - accuracy: 0.8945 - val_loss: 0.2319 - val_accuracy: 0.9124
# Epoch 12/25
# 1719/1719 [==============================] - 154s 90ms/step - loss: 0.2797 - accuracy: 0.8990 - val_loss: 0.2290 - val_accuracy: 0.9148
# Epoch 13/25
# 1719/1719 [==============================] - 152s 89ms/step - loss: 0.2698 - accuracy: 0.9010 - val_loss: 0.2205 - val_accuracy: 0.9142
# Epoch 14/25
# 1719/1719 [==============================] - 156s 91ms/step - loss: 0.2713 - accuracy: 0.9015 - val_loss: 0.2214 - val_accuracy: 0.9158
# Epoch 15/25
# 1719/1719 [==============================] - 156s 91ms/step - loss: 0.2622 - accuracy: 0.9050 - val_loss: 0.2179 - val_accuracy: 0.9184
# Epoch 16/25
# 1719/1719 [==============================] - 152s 88ms/step - loss: 0.2532 - accuracy: 0.9092 - val_loss: 0.2138 - val_accuracy: 0.9180
# Epoch 17/25
# 1719/1719 [==============================] - 152s 88ms/step - loss: 0.2491 - accuracy: 0.9094 - val_loss: 0.2082 - val_accuracy: 0.9212
# Epoch 18/25
# 1719/1719 [==============================] - 152s 88ms/step - loss: 0.2409 - accuracy: 0.9112 - val_loss: 0.2091 - val_accuracy: 0.9190
# Epoch 19/25
# 1719/1719 [==============================] - 151s 88ms/step - loss: 0.2437 - accuracy: 0.9123 - val_loss: 0.2097 - val_accuracy: 0.9190
# Epoch 20/25
# 1719/1719 [==============================] - 150s 87ms/step - loss: 0.2328 - accuracy: 0.9164 - val_loss: 0.2093 - val_accuracy: 0.9198
# Epoch 21/25
# 1719/1719 [==============================] - 152s 88ms/step - loss: 0.2283 - accuracy: 0.9144 - val_loss: 0.2047 - val_accuracy: 0.9232
# Epoch 22/25
# 1719/1719 [==============================] - 149s 87ms/step - loss: 0.2319 - accuracy: 0.9155 - val_loss: 0.2065 - val_accuracy: 0.9224
# Epoch 23/25
# 1719/1719 [==============================] - 151s 88ms/step - loss: 0.2270 - accuracy: 0.9171 - val_loss: 0.2098 - val_accuracy: 0.9214
# Epoch 24/25
# 1719/1719 [==============================] - 152s 88ms/step - loss: 0.2246 - accuracy: 0.9186 - val_loss: 0.2006 - val_accuracy: 0.9234
# Epoch 25/25
# 1719/1719 [==============================] - 152s 88ms/step - loss: 0.2171 - accuracy: 0.9197 - val_loss: 0.2057 - val_accuracy: 0.9222
# 313/313 - 5s - loss: 0.2315 - accuracy: 0.9146
#  accuracy: 91.46%
# ----------------------------

# %% [markdown]
# ### [TO COMPLETE] Example of tests discussion
# The best model that I found ...[TO COMPLETE]
# The best model i found is with first Conv2D(32, (3, 3) with Activation("relu") plus MaxPooling2D(pool_size=(2, 2) and Dropout(0.25)
# Second first Conv2D(64, (3, 3) with Activation("relu") plus MaxPooling2D(pool_size=(2, 2) and Dropout(0.25)
#
#
# The achieved accuracy in the test set is .91.46%
#
# Discussion:
#
# Pooling layers help to reduce the spatial dimensions of the input volume progressively.
#
# As the name suggests, Batch normalization seeks to normalize the activations of a given input volume before passing it into the next layer. It effectively reduces the number of epochs required to train a CNN at the expense of an increase in per-epoch time.
#
# A dropout is a form of regularization that aims to prevent overfitting. Random connections are dropped to ensure that no single node in the network is responsible for activating when presented with a given pattern.

# %% [markdown]
# Besides, I tested also other models:
#
# I tested by modifying parameters mentioned  below
#
# number of layers or neurons or filters dimension
# activation functions
# epochs
# batch sizes
# optimizer
# max-pooling
#
# Discussion:
# Fashion MNIST dataset is slightly more challenging than the MNIST digit recognition dataset, unfortunately, it cannot be used directly in real-world fashion classification tasks, unless we preprocess the images in the exact same manner as Fashion MNIST (segmentation, grayscale conversion, resizing, etc.).
