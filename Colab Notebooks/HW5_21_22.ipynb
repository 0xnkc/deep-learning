# %% [markdown]
# #**Deep Learning Homework 5: *Autoencoders***
# ### MSc Computer Science, Data Science, Cybersecurity Computer Engeneering @UniPD
# ### 2nd semester - 6 ECTS
# ### Prof. Nicolò Navarin & Prof. Alessandro Sperduti
# ---
#
#
# In this homework, we will deal with _dimensionality reduction_ and learn how to develop a simple _Autoencoder_.
# In the first part, we will learn how to develop a simple shallow autoencoder, then we will develop a deep version. Next, we will experiment with the application of autoencoder on denoising data task (denoising-autoencoder). Finally, we will apply this model to sequential domains, considering the IMDB dataset seen in HW4.

# %%
# import the usual libriaries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

np.random.seed(42)

# %% [markdown]
# ### Load Dataset
# We load the CIFAR-10 dataset, using `tf.keras.datasets`. The dataset contains 60,000 training images and 10,000 testing images.
# The images are originally in RGB format, but we will convert them to grayscale for convenience. The value of each pixel is between 0 and 255, and it represents a point of an image of size 32 x 32. We will normalize all values between 0 and 1, and we will flatten the 32x32 images into vectors of size 1024.
# Finally, since no validation set is defined, we split the test set in a validation set and a new test set.

# %%
cifar_10 = keras.datasets.cifar10
(X_train_full, _), (x_test, _) = cifar_10.load_data() # The dataset is already divede in test and training

X_train_full, x_test = np.mean(X_train_full, -1), np.mean(x_test, -1)

X_train_full = X_train_full.astype('float32') / 255
x_test = x_test.astype('float32') / 255

X_train_full = X_train_full.reshape((len(X_train_full), np.prod(X_train_full.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# We extract the first 10000 samples of the training set, to use them as the validation set
x_valid, x_train = X_train_full[:10000], X_train_full[10000:]

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.1: Singular Value Decomposition
#
# Similar to Principal component analysis (PCA), Singular Value Decomposition (SVD) is a standard linear dimensionality reduction method. They both linealry combine the features of the original high-dimensional dataset and project them into a lower-dimensional space, ideally retaing most of thier intrinsic properties.
#
# In this first part of the HW, we will focus our attention on SVD decomposition and its performances. Given a matrix $X$, the SVD decomposes it into the product of two unitary matrices $V$ and $U$ and a rectangular diagonal matrix of singular values $S$:
#
# $$ X=V \cdot S \cdot U^T.$$
#
# The SVD is already implemented in NumPy as `np.linalg.svd`. In our case, the $X$ matrix will represent the training set, where each row is a sample (therefore the number of columns will be the number of input features). However, notice that the $X$ matrix has a huge number of rows (we have 50,000 input samples) and only 784 columns. If you are using the _Colab_ free plan, the quantity of available RAM may not be sufficient to compute the SVD of $X$. Therefore, to ease memory consumption and numerical stability, we resort to one property of the SVD and compute its equivalent version from the covariance matrix $C= X^T \cdot X$, that can be decomposed as:
#
# $$ C= U \cdot S^2 \cdot U^T$$
#
# Since we need just the matrix $U$ to compute the compressed version of our data, this trick turns out to be a quick and good solution.

# %%
def SVD(X, k):
  # Compute covariance matrix
  C = np.dot(X.T, X)
  # SVD decomposition
  U, s_sqr, U_T = np.linalg.svd(C, full_matrices=False)
  # Limit the number columns of U to k
  U_k=U[:,:k]
  return U_k

# %% [markdown]
# Let's define the `ENCODING_DIM`, that will be the size of the compressed version of input data, and project the low-dimensional versions of the training set and the test set as well.

# %%
ENCODING_DIM = 120

U_k = SVD(x_train, ENCODING_DIM)

x_training_svd = np.dot(x_train, U_k)
x_test_svd = np.dot(x_test, U_k)

# %% [markdown]
# We now reconstruct back the original input and check how much information was lost due to the compression. We do so by computing the mean squared error between the original input and the reconstruction, and by plotting the reconstructed images.

# %%
x_training_reco = np.dot(x_training_svd, U_k.T)
x_test_reco = np.dot(x_test_svd, U_k.T)

# %%
accuracy_train = ((x_train - x_training_reco)**2).mean()
accuracy_test = ((x_test - x_test_reco)**2).mean()

print("Training mse: %.5f" % ( accuracy_train))
print("Test mse: %.5f" % ( accuracy_test))
# Out:
# Training mse: 0.00372
# Test mse: 0.00375

# %%
def plot_img(n, images_sets: list, title=""):
  plt.figure(figsize=(20, 4))
  for i in range(n):
    for set_idx, images in enumerate(images_sets):
      ax = plt.subplot(len(images_sets), n, i + 1 + set_idx*n)
      plt.imshow(images[i].reshape(32, 32))
      plt.gray()
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)
  plt.suptitle(title)
  plt.show()

# %% [markdown]
# Let's see how well the input can be reconstructed by displaying a few of the input images and the corresponding reconstructions. Obviously, all these evaluations have to be done on the test set.
#
# The first row of images corresponds to input data, while the second one contains the reconstructions.

# %%
plot_img(10, [x_test, x_test_reco], title = "Original (top) vs Reconstructed (bottom)")

# %% [markdown]
# **[TO COMPLETE]**: What happens by varying the `ENCODING_DIM`? Try it out and discuss the results in this cell.
#
# _Answer:_
#
# I have tested with some values for the ENCODING_DIM the lowest i tryed is 1 which corresponds to taking the most important principal component of the decomposition. some times we can't even predict the real number for example 8 or 9.
#
# If you decrease the ENCODING_DIM value the MSE value will increse and the recostrected images are less clear and less pixel in the image.
#
# This means that, according to PCA, the most meaningful information is that the number itself is white and well centered on the image, while the background is black. Using 50 dimensions, the reconstructed images looks a bit blurried but the number are very distinguishable.

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.2: Shallow Linear Autoencoder
# Let's define a model that consists of a single fully-connected neural layer. The hidden layer and the output layer act as the encoder and the decoder, respectively. Differently than the previous HW when we used `Keras.Sequential()`, here we define the two parts of the model (encoder and decoder) separately and then we create the final model.

# %%
ENCODING_DIM = 256
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
# Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='linear')(input_img)

# ...the decoder...
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='linear')(encoded)

# and the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

# Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse')

# %% [markdown]
# Print the model summary.

# %%
autoencoder.summary()
# Out:
# Model: "model_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 1024)]            0
#
#  dense_14 (Dense)            (None, 256)               262400
#
#  dense_15 (Dense)            (None, 1024)              263168
#
# =================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model.

# %%
history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/15
# 79/79 [==============================] - 3s 39ms/step - loss: 0.1820 - val_loss: 0.0304
# Epoch 2/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0418 - val_loss: 0.0215
# Epoch 3/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0189 - val_loss: 0.0168
# Epoch 4/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0200 - val_loss: 0.0140
# Epoch 5/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0128 - val_loss: 0.0120
# Epoch 6/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0112 - val_loss: 0.0106
# Epoch 7/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0100 - val_loss: 0.0096
# Epoch 8/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0091 - val_loss: 0.0087
# Epoch 9/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0096 - val_loss: 0.0086
# Epoch 10/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 11/15
# 79/79 [==============================] - 3s 38ms/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 12/15
# 79/79 [==============================] - 3s 38ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 13/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 14/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 15/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0054 - val_loss: 0.0054

# %% [markdown]
# Plot the loss and the accuracy curves on the validation set, and the accuracy on the test set.

# %%
def plot_loss(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['loss'])
  plt.plot(history.epoch,history.history['val_loss'])
  plt.grid()
  plt.title('loss')

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("Test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0053 - 827ms/epoch - 3ms/step
# Test mse: 0.00534

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")

# %% [markdown]
# **[TO COMPLETE]** Check the results and compare them versus the results obtained with the SVD. Give an explanation of the relation between the results obtained  by the shallow linear autoencoder and the ones obtained by the SVD decomposition.
#
#
# _Answer:_
#
# Because Singular value decomposition and shallow linear autoencoder are connected, the findings are comparable. The pictures produced by the shallow Linear Autoencoder are grainier, but the images produced by the singular value decomposition are smooth. Also, there isn't much of a difference in mse values, with SVD having 0.00375 and SLA having 0.00534.

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.3: Shallow Non-linear Autoencoders
#
# **[TO COMPLETE]** Replicate the code of Exercise 5.2 but in this case, instead of using linear activation functions use non-linear ones. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained in Exercise 5.2.
#
# Insert your code and theoretical discussion into cells immediately below this one.

# %%
ENCODING_DIM = 120
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
# Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='sigmoid')(input_img)

# ...the decoder...
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(encoded)

# and the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

# Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse')

autoencoder.summary()
# Out:
# Model: "model_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 1024)]            0
#
#  dense_16 (Dense)            (None, 120)               123000
#
#  dense_17 (Dense)            (None, 1024)              123904
#
# =================================================================
# Total params: 246,904
# Trainable params: 246,904
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))

plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("Test mse: %.5f" % (scores))

encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")
# Out:
# Epoch 1/15
# 79/79 [==============================] - 2s 27ms/step - loss: 0.0377 - val_loss: 0.0255
# Epoch 2/15
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0215 - val_loss: 0.0190
# Epoch 3/15
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0172 - val_loss: 0.0153
# Epoch 4/15
# 79/79 [==============================] - 2s 24ms/step - loss: 0.0149 - val_loss: 0.0138
# Epoch 5/15
# 79/79 [==============================] - 2s 25ms/step - loss: 0.0132 - val_loss: 0.0122
# Epoch 6/15
# 79/79 [==============================] - 2s 24ms/step - loss: 0.0124 - val_loss: 0.0115
# Epoch 7/15
# 79/79 [==============================] - 2s 24ms/step - loss: 0.0113 - val_loss: 0.0113
# Epoch 8/15
# 79/79 [==============================] - 2s 24ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 9/15
# 79/79 [==============================] - 2s 24ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 10/15
# 79/79 [==============================] - 2s 25ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 11/15
# 79/79 [==============================] - 2s 24ms/step - loss: 0.0095 - val_loss: 0.0094
# Epoch 12/15
# 79/79 [==============================] - 2s 24ms/step - loss: 0.0091 - val_loss: 0.0088
# Epoch 13/15
# 79/79 [==============================] - 2s 24ms/step - loss: 0.0089 - val_loss: 0.0083
# Epoch 14/15
# 79/79 [==============================] - 2s 24ms/step - loss: 0.0088 - val_loss: 0.0082
# Epoch 15/15
# 79/79 [==============================] - 2s 24ms/step - loss: 0.0084 - val_loss: 0.0081
# 313/313 - 1s - loss: 0.0081 - 621ms/epoch - 2ms/step
# Test mse: 0.00807

# %% [markdown]
# After running the both shallow linear autoencoders and shallow non linear autoencoders we can see the mean squared error is almost the same but the non liner autoencoder gives the better results and we can see the decoded images are more detailed (means good quality) because of the nonlinear auto-encoder.
#
# comes to the activation function for the nonlinear autoencoder i tryed tanh, sigmoid, ReLu. at the end i selected sigmoid because its give me a better results.

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.4: Deep Autoencoder
# **[TO COMPLETE]** Build a deep version of the Autoencoder defined above. The autoencoder has to use at least 5 layers. The model will use $n$ layers for encoding, and $n-1$ for decoding. The layers sizes of the encoding part decrease at each layer (e.g., `INPUT_DIM->128->64`, where 64 is the encoding dim). The decoding part layers dimensions progression turns out to be mirrored (e.g., `128->INPUT_DIM`, the final overall structure recalls an hourglass ⏳).
# As usual, print the model summary, the loss curves during the training, the achieved loss on the test set, and some input images with the corresponding decoding.

# %%
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))

encoded = tf.keras.layers.Dense(128, activation='relu')(input_img)
encoded = tf.keras.layers.Dense(64, activation='relu')(encoded)
encoded = tf.keras.layers.Dense(32, activation='relu')(encoded)

decoded = tf.keras.layers.Dense(64, activation='relu')(encoded)
decoded = tf.keras.layers.Dense(128, activation='relu')(decoded)
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(decoded)

autoencoder = tf.keras.models.Model(input_img, decoded) #[TO COMPLETE]

autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 1024)]            0
#
#  dense_18 (Dense)            (None, 128)               131200
#
#  dense_19 (Dense)            (None, 64)                8256
#
#  dense_20 (Dense)            (None, 32)                2080
#
#  dense_21 (Dense)            (None, 64)                2112
#
#  dense_22 (Dense)            (None, 128)               8320
#
#  dense_23 (Dense)            (None, 1024)              132096
#
# =================================================================
# Total params: 284,064
# Trainable params: 284,064
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(x_train, x_train, epochs=100, batch_size= 256, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/100
# 157/157 [==============================] - 4s 19ms/step - loss: 0.0341 - val_loss: 0.0275
# Epoch 2/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0248 - val_loss: 0.0255
# Epoch 3/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0220 - val_loss: 0.0217
# Epoch 4/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0211 - val_loss: 0.0209
# Epoch 5/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0197 - val_loss: 0.0195
# Epoch 6/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0193 - val_loss: 0.0194
# Epoch 7/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0192 - val_loss: 0.0196
# Epoch 8/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0192 - val_loss: 0.0194
# Epoch 9/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0188 - val_loss: 0.0182
# Epoch 10/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0178 - val_loss: 0.0179
# Epoch 11/100
# 157/157 [==============================] - 4s 25ms/step - loss: 0.0176 - val_loss: 0.0177
# Epoch 12/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0176 - val_loss: 0.0177
# Epoch 13/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0178 - val_loss: 0.0177
# Epoch 14/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0174 - val_loss: 0.0173
# Epoch 15/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0168 - val_loss: 0.0165
# Epoch 16/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0164 - val_loss: 0.0165
# Epoch 17/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0163 - val_loss: 0.0164
# Epoch 18/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0163 - val_loss: 0.0165
# Epoch 19/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0163 - val_loss: 0.0163
# Epoch 20/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0162 - val_loss: 0.0166
# Epoch 21/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 22/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0163 - val_loss: 0.0167
# Epoch 23/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 24/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0161 - val_loss: 0.0166
# Epoch 25/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0161 - val_loss: 0.0163
# Epoch 26/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0161 - val_loss: 0.0161
# Epoch 27/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0158 - val_loss: 0.0160
# Epoch 28/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0156 - val_loss: 0.0159
# Epoch 29/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0156 - val_loss: 0.0159
# Epoch 30/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0156 - val_loss: 0.0157
# Epoch 31/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0155 - val_loss: 0.0156
# Epoch 32/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0155 - val_loss: 0.0157
# Epoch 33/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0155 - val_loss: 0.0160
# Epoch 34/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0155 - val_loss: 0.0157
# Epoch 35/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0155 - val_loss: 0.0156
# Epoch 36/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0155 - val_loss: 0.0159
# Epoch 37/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0155 - val_loss: 0.0156
# Epoch 38/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0155 - val_loss: 0.0158
# Epoch 39/100
# 157/157 [==============================] - 3s 21ms/step - loss: 0.0155 - val_loss: 0.0157
# Epoch 40/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0155 - val_loss: 0.0156
# Epoch 41/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0155 - val_loss: 0.0158
# Epoch 42/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0154 - val_loss: 0.0156
# Epoch 43/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0154 - val_loss: 0.0159
# Epoch 44/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0154 - val_loss: 0.0155
# Epoch 45/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0154 - val_loss: 0.0156
# Epoch 46/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0154 - val_loss: 0.0158
# Epoch 47/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0154 - val_loss: 0.0157
# Epoch 48/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0154 - val_loss: 0.0156
# Epoch 49/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0154 - val_loss: 0.0155
# Epoch 50/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0154 - val_loss: 0.0155
# Epoch 51/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0154 - val_loss: 0.0156
# Epoch 52/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0154 - val_loss: 0.0156
# Epoch 53/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0154 - val_loss: 0.0157
# Epoch 54/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0151 - val_loss: 0.0154
# Epoch 55/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0149 - val_loss: 0.0152
# Epoch 56/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0149 - val_loss: 0.0149
# Epoch 57/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0149 - val_loss: 0.0153
# Epoch 58/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0149 - val_loss: 0.0151
# Epoch 59/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0155
# Epoch 60/100
# 157/157 [==============================] - 3s 22ms/step - loss: 0.0148 - val_loss: 0.0153
# Epoch 61/100
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0148 - val_loss: 0.0152
# Epoch 62/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0149 - val_loss: 0.0150
# Epoch 63/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 64/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0151
# Epoch 65/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 66/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0148 - val_loss: 0.0151
# Epoch 67/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 68/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0148 - val_loss: 0.0153
# Epoch 69/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0148 - val_loss: 0.0152
# Epoch 70/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0148 - val_loss: 0.0151
# Epoch 71/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0148 - val_loss: 0.0149
# Epoch 72/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 73/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0155
# Epoch 74/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0151
# Epoch 75/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0148 - val_loss: 0.0149
# Epoch 76/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0149
# Epoch 77/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0152
# Epoch 78/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 79/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0152
# Epoch 80/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 81/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0147 - val_loss: 0.0150
# Epoch 82/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0152
# Epoch 83/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0149
# Epoch 84/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0148
# Epoch 85/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0147 - val_loss: 0.0150
# Epoch 86/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0147 - val_loss: 0.0151
# Epoch 87/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0147 - val_loss: 0.0151
# Epoch 88/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0147 - val_loss: 0.0151
# Epoch 89/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0148 - val_loss: 0.0149
# Epoch 90/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0147 - val_loss: 0.0149
# Epoch 91/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0147 - val_loss: 0.0149
# Epoch 92/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 93/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0147 - val_loss: 0.0150
# Epoch 94/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0151
# Epoch 95/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0147 - val_loss: 0.0149
# Epoch 96/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0147 - val_loss: 0.0150
# Epoch 97/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0147 - val_loss: 0.0150
# Epoch 98/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0147 - val_loss: 0.0150
# Epoch 99/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0147 - val_loss: 0.0149
# Epoch 100/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0147 - val_loss: 0.0150

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0150 - 667ms/epoch - 2ms/step
# test mse: 0.01495

# %%
decoded_imgs = autoencoder.predict(x_test)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.5: Denoising Autoencoder
#
# Let's now use a shallow autoencoder to denoise the input data. The idea is that only meaningful information will be encoded, thus filtering out useless noise.
# Firstly, define a noisy input by adding some gaussian noise to our input data. We define a noise factor that can be used to modify the amount of noise to add to the input data. Check how much it influences the denoising capability of the autoencoder.

# %%
noise_factor = 0.3

x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_valid_noisy = x_valid + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_valid.shape)

# we still have to be sure that the color values are in the [0,1] range:
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
x_valid_noisy = np.clip(x_valid_noisy, 0., 1.)

# %% [markdown]
# Plot some noisy inputs:

# %%
plot_img(10, [x_test_noisy, x_test], title = "Noisy (top) vs Original (bottom)")

# %% [markdown]
# **[TO COMPLETE]** Define a shallow autoencoder able to compute a de-noised version of the input (use a noise_factor $\geq 0.3$).

# %%
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))

encoded = tf.keras.layers.Dense(128, activation='sigmoid')(input_img)

decoded = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(encoded)

autoencoder = tf.keras.models.Model(input_img, decoded)

autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse') #[TO COMPLETE]

# %%
autoencoder.summary()
# Out:
# Model: "model_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_25 (InputLayer)       [(None, 1024)]            0
#
#  dense_24 (Dense)            (None, 128)               131200
#
#  dense_25 (Dense)            (None, 1024)              132096
#
# =================================================================
# Total params: 263,296
# Trainable params: 263,296
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **[TO COMPLETE]** Train the model by passing the noisy input and the clean target.

# %%
history = autoencoder.fit(x_train_noisy, x_train, epochs= 120, batch_size= 256, shuffle=True, validation_data=(x_valid_noisy, x_valid))
# Out:
# Epoch 1/120
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0316 - val_loss: 0.0214
# Epoch 2/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0198 - val_loss: 0.0174
# Epoch 3/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0163 - val_loss: 0.0153
# Epoch 4/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0149 - val_loss: 0.0145
# Epoch 5/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0141 - val_loss: 0.0138
# Epoch 6/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0137 - val_loss: 0.0135
# Epoch 7/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0130 - val_loss: 0.0136
# Epoch 8/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0127 - val_loss: 0.0125
# Epoch 9/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0126 - val_loss: 0.0123
# Epoch 10/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0124 - val_loss: 0.0124
# Epoch 11/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0122 - val_loss: 0.0123
# Epoch 12/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0120 - val_loss: 0.0124
# Epoch 13/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0120 - val_loss: 0.0123
# Epoch 14/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0118 - val_loss: 0.0120
# Epoch 15/120
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0118 - val_loss: 0.0123
# Epoch 16/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0118 - val_loss: 0.0133
# Epoch 17/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0117 - val_loss: 0.0126
# Epoch 18/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0115 - val_loss: 0.0130
# Epoch 19/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0115 - val_loss: 0.0137
# Epoch 20/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 21/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0114 - val_loss: 0.0120
# Epoch 22/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 23/120
# 157/157 [==============================] - 3s 20ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 24/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 25/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0114 - val_loss: 0.0116
# Epoch 26/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0113 - val_loss: 0.0116
# Epoch 27/120
# 157/157 [==============================] - 3s 22ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 28/120
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 29/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0110 - val_loss: 0.0139
# Epoch 30/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0112 - val_loss: 0.0115
# Epoch 31/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 32/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0111 - val_loss: 0.0116
# Epoch 33/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0110 - val_loss: 0.0127
# Epoch 34/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0111 - val_loss: 0.0113
# Epoch 35/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 36/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0110 - val_loss: 0.0113
# Epoch 37/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0111 - val_loss: 0.0114
# Epoch 38/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 39/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0110 - val_loss: 0.0113
# Epoch 40/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0109 - val_loss: 0.0112
# Epoch 41/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0109 - val_loss: 0.0120
# Epoch 42/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 43/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0109 - val_loss: 0.0117
# Epoch 44/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0113
# Epoch 45/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 46/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0111
# Epoch 47/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0113
# Epoch 48/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 49/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0111
# Epoch 50/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0121
# Epoch 51/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0111
# Epoch 52/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0115
# Epoch 53/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0118
# Epoch 54/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0107 - val_loss: 0.0112
# Epoch 55/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 56/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0115
# Epoch 57/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0113
# Epoch 58/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0111
# Epoch 59/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0115
# Epoch 60/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0114
# Epoch 61/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0107 - val_loss: 0.0110
# Epoch 62/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0107 - val_loss: 0.0111
# Epoch 63/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0107 - val_loss: 0.0110
# Epoch 64/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 65/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0107 - val_loss: 0.0114
# Epoch 66/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0112
# Epoch 67/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0113
# Epoch 68/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0115
# Epoch 69/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0112
# Epoch 70/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 71/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0112
# Epoch 72/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0107 - val_loss: 0.0111
# Epoch 73/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0107 - val_loss: 0.0117
# Epoch 74/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0111
# Epoch 75/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0107 - val_loss: 0.0114
# Epoch 76/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0114
# Epoch 77/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 78/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 79/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0126
# Epoch 80/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0115
# Epoch 81/120
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0107 - val_loss: 0.0113
# Epoch 82/120
# 157/157 [==============================] - 3s 21ms/step - loss: 0.0106 - val_loss: 0.0113
# Epoch 83/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0112
# Epoch 84/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0120
# Epoch 85/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0110
# Epoch 86/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0110
# Epoch 87/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0116
# Epoch 88/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0116
# Epoch 89/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 90/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0113
# Epoch 91/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0116
# Epoch 92/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0111
# Epoch 93/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0109
# Epoch 94/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0115
# Epoch 95/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 96/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0109
# Epoch 97/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0110
# Epoch 98/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0110
# Epoch 99/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0110
# Epoch 100/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0110
# Epoch 101/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0110
# Epoch 102/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0109
# Epoch 103/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0111
# Epoch 104/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0109
# Epoch 105/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0109
# Epoch 106/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0111
# Epoch 107/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0112
# Epoch 108/120
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0106 - val_loss: 0.0110
# Epoch 109/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 110/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0110
# Epoch 111/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0127
# Epoch 112/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0109
# Epoch 113/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 114/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0112
# Epoch 115/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0104 - val_loss: 0.0113
# Epoch 116/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 117/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0118
# Epoch 118/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0114
# Epoch 119/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0105 - val_loss: 0.0110
# Epoch 120/120
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0106 - val_loss: 0.0111

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test_noisy, x_test, verbose=2)
print("Test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0111 - 619ms/epoch - 2ms/step
# Test mse: 0.01111

# %% [markdown]
# **[TO COMPLETE]** Check the result by plotting some input images and the corresponding denoised outputs.

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

plot_img(10, [x_test_noisy, x_test, decoded_imgs])

# %% [markdown]
# ## Exercise 5.6: Linear Autoencoder for sequences
#
# Let's define a linear autoencoder for sequences. In this case we will use the IMDB dataset (already introduced in HW4). To have a model that can be trained and tested in a reasonable time (and that works also with the memory limitation that we have in _Colab_), we will limit the number of training samples and test samples.

# %%
num_words = 100
(X_train, _), (X_test, _) = keras.datasets.imdb.load_data(num_words=num_words)

X_train=X_train[:10000]

(X_valid, X_test) = X_test[:1250], X_test[-1250:]

word_index = keras.datasets.imdb.get_word_index()

reverse_index = {word_id + 3: word for word, word_id in word_index.items()}
reverse_index[0] = "<pad>" # padding
reverse_index[1] = "<sos>" # start of sequence
reverse_index[2] = "<oov>" # out-of-vocabulary
reverse_index[3] = "<unk>" # unknown

def decode_review(word_ids):
    return " ".join([reverse_index.get(word_id, "<err>") for word_id in word_ids])

maxlen = 90
X_train_trim = keras.preprocessing.sequence.pad_sequences(X_train, maxlen=maxlen)
X_test_trim = keras.preprocessing.sequence.pad_sequences(X_test, maxlen=maxlen)
X_valid_trim = keras.preprocessing.sequence.pad_sequences(X_valid, maxlen=maxlen)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step
# 1654784/1641221 [==============================] - 0s 0us/step

# %% [markdown]
# In this case, we want to use as input/target a one-hot representation for each word. To convert the index representation provided by IMDB dataset loader we use the to_categorical method to transform them in the corresponding one hot representation.

# %%
from tensorflow.keras.utils import to_categorical


X_train_one_hot=to_categorical(X_train_trim)
X_test_one_hot=to_categorical(X_test_trim)
X_valid_one_hot=to_categorical(X_valid_trim)

# %% [markdown]
# Define a linear shallow autoencoder for sequences. The structure will be similar to the model defined in Exercise 5.2, while the used encoding layer is defined by using `tf.keras.layers.SimpleRNN`. Note that it uses linear activations. The decoding layer exploits [tf.keras.layers.TimeDistributed](https://www.tensorflow.org/api_docs/python/tf/keras/layers/TimeDistributed) that allows using the same dense cell at each time step of the sequence.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))
encoded = tf.keras.layers.SimpleRNN(50, return_sequences=True, activation='linear')(inputs)

decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='linear'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()
# Out:
# Model: "model_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_26 (InputLayer)       [(None, 90, 100)]         0
#
#  simple_rnn (SimpleRNN)      (None, 90, 50)            7550
#
#  time_distributed (TimeDistr  (None, 90, 100)          5100
#  ibuted)
#
# =================================================================
# Total params: 12,650
# Trainable params: 12,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=128, shuffle=True, validation_data=(X_valid_one_hot, X_valid_one_hot))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 8s 86ms/step - loss: 0.1962 - categorical_accuracy: 0.1589 - val_loss: 0.0875 - val_categorical_accuracy: 0.3868
# Epoch 2/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0739 - categorical_accuracy: 0.4565 - val_loss: 0.0685 - val_categorical_accuracy: 0.4768
# Epoch 3/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0641 - categorical_accuracy: 0.5075 - val_loss: 0.0602 - val_categorical_accuracy: 0.5249
# Epoch 4/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0552 - categorical_accuracy: 0.5490 - val_loss: 0.0517 - val_categorical_accuracy: 0.5596
# Epoch 5/50
# 79/79 [==============================] - 7s 93ms/step - loss: 0.0498 - categorical_accuracy: 0.5522 - val_loss: 0.0460 - val_categorical_accuracy: 0.5865
# Epoch 6/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0444 - categorical_accuracy: 0.6167 - val_loss: 0.0439 - val_categorical_accuracy: 0.6351
# Epoch 7/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0405 - categorical_accuracy: 0.6586 - val_loss: 0.0377 - val_categorical_accuracy: 0.6644
# Epoch 8/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0348 - categorical_accuracy: 0.6779 - val_loss: 0.0341 - val_categorical_accuracy: 0.6953
# Epoch 9/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0311 - categorical_accuracy: 0.6994 - val_loss: 0.0299 - val_categorical_accuracy: 0.6967
# Epoch 10/50
# 79/79 [==============================] - 6s 82ms/step - loss: 0.0279 - categorical_accuracy: 0.6968 - val_loss: 0.0274 - val_categorical_accuracy: 0.6868
# Epoch 11/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0256 - categorical_accuracy: 0.7098 - val_loss: 0.0250 - val_categorical_accuracy: 0.7169
# Epoch 12/50
# 79/79 [==============================] - 7s 82ms/step - loss: 0.0237 - categorical_accuracy: 0.7437 - val_loss: 0.0233 - val_categorical_accuracy: 0.7417
# Epoch 13/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0221 - categorical_accuracy: 0.7375 - val_loss: 0.0220 - val_categorical_accuracy: 0.7421
# Epoch 14/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0208 - categorical_accuracy: 0.7628 - val_loss: 0.0207 - val_categorical_accuracy: 0.7611
# Epoch 15/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0197 - categorical_accuracy: 0.7764 - val_loss: 0.0196 - val_categorical_accuracy: 0.7866
# Epoch 16/50
# 79/79 [==============================] - 6s 82ms/step - loss: 0.0187 - categorical_accuracy: 0.7992 - val_loss: 0.0188 - val_categorical_accuracy: 0.8131
# Epoch 17/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0180 - categorical_accuracy: 0.8249 - val_loss: 0.0180 - val_categorical_accuracy: 0.8317
# Epoch 18/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0173 - categorical_accuracy: 0.8415 - val_loss: 0.0174 - val_categorical_accuracy: 0.8614
# Epoch 19/50
# 79/79 [==============================] - 7s 82ms/step - loss: 0.0166 - categorical_accuracy: 0.8600 - val_loss: 0.0167 - val_categorical_accuracy: 0.8613
# Epoch 20/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0160 - categorical_accuracy: 0.8739 - val_loss: 0.0160 - val_categorical_accuracy: 0.8749
# Epoch 21/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0154 - categorical_accuracy: 0.8851 - val_loss: 0.0155 - val_categorical_accuracy: 0.8890
# Epoch 22/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0150 - categorical_accuracy: 0.8966 - val_loss: 0.0151 - val_categorical_accuracy: 0.9005
# Epoch 23/50
# 79/79 [==============================] - 7s 82ms/step - loss: 0.0146 - categorical_accuracy: 0.9080 - val_loss: 0.0148 - val_categorical_accuracy: 0.9142
# Epoch 24/50
# 79/79 [==============================] - 9s 111ms/step - loss: 0.0142 - categorical_accuracy: 0.9148 - val_loss: 0.0143 - val_categorical_accuracy: 0.9140
# Epoch 25/50
# 79/79 [==============================] - 8s 100ms/step - loss: 0.0137 - categorical_accuracy: 0.9196 - val_loss: 0.0139 - val_categorical_accuracy: 0.9214
# Epoch 26/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0134 - categorical_accuracy: 0.9254 - val_loss: 0.0135 - val_categorical_accuracy: 0.9256
# Epoch 27/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0131 - categorical_accuracy: 0.9299 - val_loss: 0.0133 - val_categorical_accuracy: 0.9295
# Epoch 28/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0128 - categorical_accuracy: 0.9335 - val_loss: 0.0130 - val_categorical_accuracy: 0.9326
# Epoch 29/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0126 - categorical_accuracy: 0.9361 - val_loss: 0.0128 - val_categorical_accuracy: 0.9352
# Epoch 30/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0124 - categorical_accuracy: 0.9383 - val_loss: 0.0126 - val_categorical_accuracy: 0.9374
# Epoch 31/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0122 - categorical_accuracy: 0.9402 - val_loss: 0.0124 - val_categorical_accuracy: 0.9390
# Epoch 32/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0120 - categorical_accuracy: 0.9418 - val_loss: 0.0122 - val_categorical_accuracy: 0.9405
# Epoch 33/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0118 - categorical_accuracy: 0.9431 - val_loss: 0.0120 - val_categorical_accuracy: 0.9418
# Epoch 34/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0116 - categorical_accuracy: 0.9442 - val_loss: 0.0118 - val_categorical_accuracy: 0.9428
# Epoch 35/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0115 - categorical_accuracy: 0.9451 - val_loss: 0.0117 - val_categorical_accuracy: 0.9436
# Epoch 36/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0113 - categorical_accuracy: 0.9457 - val_loss: 0.0115 - val_categorical_accuracy: 0.9444
# Epoch 37/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0111 - categorical_accuracy: 0.9464 - val_loss: 0.0113 - val_categorical_accuracy: 0.9452
# Epoch 38/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0110 - categorical_accuracy: 0.9469 - val_loss: 0.0112 - val_categorical_accuracy: 0.9457
# Epoch 39/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0108 - categorical_accuracy: 0.9474 - val_loss: 0.0110 - val_categorical_accuracy: 0.9461
# Epoch 40/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0107 - categorical_accuracy: 0.9478 - val_loss: 0.0109 - val_categorical_accuracy: 0.9465
# Epoch 41/50
# 79/79 [==============================] - 7s 85ms/step - loss: 0.0105 - categorical_accuracy: 0.9481 - val_loss: 0.0107 - val_categorical_accuracy: 0.9468
# Epoch 42/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0104 - categorical_accuracy: 0.9484 - val_loss: 0.0106 - val_categorical_accuracy: 0.9472
# Epoch 43/50
# 79/79 [==============================] - 8s 99ms/step - loss: 0.0103 - categorical_accuracy: 0.9486 - val_loss: 0.0105 - val_categorical_accuracy: 0.9474
# Epoch 44/50
# 79/79 [==============================] - 7s 85ms/step - loss: 0.0102 - categorical_accuracy: 0.9488 - val_loss: 0.0103 - val_categorical_accuracy: 0.9477
# Epoch 45/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0100 - categorical_accuracy: 0.9490 - val_loss: 0.0102 - val_categorical_accuracy: 0.9478
# Epoch 46/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0099 - categorical_accuracy: 0.9491 - val_loss: 0.0101 - val_categorical_accuracy: 0.9479
# Epoch 47/50
# 79/79 [==============================] - 7s 85ms/step - loss: 0.0098 - categorical_accuracy: 0.9492 - val_loss: 0.0100 - val_categorical_accuracy: 0.9480
# Epoch 48/50
# 79/79 [==============================] - 7s 85ms/step - loss: 0.0097 - categorical_accuracy: 0.9493 - val_loss: 0.0099 - val_categorical_accuracy: 0.9481
# Epoch 49/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0096 - categorical_accuracy: 0.9494 - val_loss: 0.0098 - val_categorical_accuracy: 0.9482
# Epoch 50/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0095 - categorical_accuracy: 0.9495 - val_loss: 0.0097 - val_categorical_accuracy: 0.9483

# %% [markdown]
# Let's plot the accuracy and the loss trends and check the reconstruction capability of the model by plotting the reconstruction of a test sample

# %%
def plot_categorical_accuracy(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['categorical_accuracy'])
  plt.plot(history.epoch,history.history['val_categorical_accuracy'])
  plt.title('accuracy')

plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))
# Out:
# 40/40 - 1s - loss: 0.0096 - categorical_accuracy: 0.9484 - 521ms/epoch - 13ms/step
# categorical_accuracy: 94.84%

# %%
decoded_text = sequence_autoencoder.predict(X_test_one_hot)
decode_index= np.argmax(decoded_text[500], axis=1)
input_text= np.argmax(X_test_one_hot[500], axis=1)

print(decode_review(input_text))
print(decode_review(decode_index))
# Out:
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>
# <oov> a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> it in i one <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the and are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really was can that <oov> <oov> <oov> really so <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.7: Non-Linear Autoencoder for sequences
# **[TO COMPLETE]**: Replicate the code of the above exercise, but instead of using a simpleRNN with linear activation do the same  using  non-linear activation functions and using an LSTM layer. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained by the linear autoencoder for sequences.
#
# Hint: using a non-linear function also in the dense layer after the RNN/LSTM one will help to obtain better results. The choice of this function should be based on the type of output data.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))
encoded = tf.keras.layers.LSTM(50, return_sequences=True, activation='sigmoid')(inputs)

decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='softmax'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()

history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=256, shuffle=True, validation_data=(X_valid_one_hot, X_valid_one_hot))


plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))

decoded_text = sequence_autoencoder.predict(X_test_one_hot)
decode_index= np.argmax(decoded_text[500], axis=1)
input_text= np.argmax(X_test_one_hot[500], axis=1)

print(decode_review(input_text))
print(decode_review(decode_index))
# Out:
# Model: "model_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 90, 100)]         0
#
#  lstm (LSTM)                 (None, 90, 50)            30200
#
#  time_distributed_1 (TimeDis  (None, 90, 100)          5100
#  tributed)
#
# =================================================================
# Total params: 35,300
# Trainable params: 35,300
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 40/40 [==============================] - 13s 277ms/step - loss: 0.0497 - categorical_accuracy: 0.3225 - val_loss: 0.0420 - val_categorical_accuracy: 0.4620
# Epoch 2/50
# 40/40 [==============================] - 11s 272ms/step - loss: 0.0381 - categorical_accuracy: 0.4711 - val_loss: 0.0372 - val_categorical_accuracy: 0.4614
# Epoch 3/50
# 40/40 [==============================] - 12s 303ms/step - loss: 0.0365 - categorical_accuracy: 0.4710 - val_loss: 0.0367 - val_categorical_accuracy: 0.4614
# Epoch 4/50
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0361 - categorical_accuracy: 0.4710 - val_loss: 0.0362 - val_categorical_accuracy: 0.4614
# Epoch 5/50
# 40/40 [==============================] - 11s 279ms/step - loss: 0.0354 - categorical_accuracy: 0.4710 - val_loss: 0.0354 - val_categorical_accuracy: 0.4614
# Epoch 6/50
# 40/40 [==============================] - 11s 273ms/step - loss: 0.0343 - categorical_accuracy: 0.4710 - val_loss: 0.0340 - val_categorical_accuracy: 0.4614
# Epoch 7/50
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0327 - categorical_accuracy: 0.4710 - val_loss: 0.0322 - val_categorical_accuracy: 0.4614
# Epoch 8/50
# 40/40 [==============================] - 11s 273ms/step - loss: 0.0307 - categorical_accuracy: 0.4710 - val_loss: 0.0300 - val_categorical_accuracy: 0.4614
# Epoch 9/50
# 40/40 [==============================] - 11s 276ms/step - loss: 0.0284 - categorical_accuracy: 0.4710 - val_loss: 0.0275 - val_categorical_accuracy: 0.4614
# Epoch 10/50
# 40/40 [==============================] - 11s 273ms/step - loss: 0.0259 - categorical_accuracy: 0.4851 - val_loss: 0.0249 - val_categorical_accuracy: 0.5094
# Epoch 11/50
# 40/40 [==============================] - 11s 272ms/step - loss: 0.0232 - categorical_accuracy: 0.5922 - val_loss: 0.0222 - val_categorical_accuracy: 0.6691
# Epoch 12/50
# 40/40 [==============================] - 11s 271ms/step - loss: 0.0207 - categorical_accuracy: 0.7160 - val_loss: 0.0198 - val_categorical_accuracy: 0.7434
# Epoch 13/50
# 40/40 [==============================] - 11s 273ms/step - loss: 0.0184 - categorical_accuracy: 0.7590 - val_loss: 0.0175 - val_categorical_accuracy: 0.7625
# Epoch 14/50
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0162 - categorical_accuracy: 0.7790 - val_loss: 0.0155 - val_categorical_accuracy: 0.7862
# Epoch 15/50
# 40/40 [==============================] - 12s 299ms/step - loss: 0.0143 - categorical_accuracy: 0.8036 - val_loss: 0.0137 - val_categorical_accuracy: 0.8125
# Epoch 16/50
# 40/40 [==============================] - 11s 271ms/step - loss: 0.0127 - categorical_accuracy: 0.8239 - val_loss: 0.0122 - val_categorical_accuracy: 0.8257
# Epoch 17/50
# 40/40 [==============================] - 11s 273ms/step - loss: 0.0113 - categorical_accuracy: 0.8358 - val_loss: 0.0109 - val_categorical_accuracy: 0.8366
# Epoch 18/50
# 40/40 [==============================] - 11s 273ms/step - loss: 0.0101 - categorical_accuracy: 0.8468 - val_loss: 0.0097 - val_categorical_accuracy: 0.8511
# Epoch 19/50
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0090 - categorical_accuracy: 0.8667 - val_loss: 0.0087 - val_categorical_accuracy: 0.8709
# Epoch 20/50
# 40/40 [==============================] - 11s 278ms/step - loss: 0.0080 - categorical_accuracy: 0.8824 - val_loss: 0.0078 - val_categorical_accuracy: 0.8909
# Epoch 21/50
# 40/40 [==============================] - 11s 272ms/step - loss: 0.0072 - categorical_accuracy: 0.9023 - val_loss: 0.0069 - val_categorical_accuracy: 0.9069
# Epoch 22/50
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0064 - categorical_accuracy: 0.9111 - val_loss: 0.0062 - val_categorical_accuracy: 0.9109
# Epoch 23/50
# 40/40 [==============================] - 11s 276ms/step - loss: 0.0057 - categorical_accuracy: 0.9198 - val_loss: 0.0055 - val_categorical_accuracy: 0.9256
# Epoch 24/50
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0050 - categorical_accuracy: 0.9327 - val_loss: 0.0049 - val_categorical_accuracy: 0.9351
# Epoch 25/50
# 40/40 [==============================] - 11s 279ms/step - loss: 0.0045 - categorical_accuracy: 0.9413 - val_loss: 0.0043 - val_categorical_accuracy: 0.9446
# Epoch 26/50
# 40/40 [==============================] - 12s 302ms/step - loss: 0.0039 - categorical_accuracy: 0.9502 - val_loss: 0.0038 - val_categorical_accuracy: 0.9520
# Epoch 27/50
# 40/40 [==============================] - 11s 272ms/step - loss: 0.0035 - categorical_accuracy: 0.9579 - val_loss: 0.0033 - val_categorical_accuracy: 0.9607
# Epoch 28/50
# 40/40 [==============================] - 11s 272ms/step - loss: 0.0031 - categorical_accuracy: 0.9666 - val_loss: 0.0029 - val_categorical_accuracy: 0.9695
# Epoch 29/50
# 40/40 [==============================] - 11s 272ms/step - loss: 0.0027 - categorical_accuracy: 0.9744 - val_loss: 0.0026 - val_categorical_accuracy: 0.9767
# Epoch 30/50
# 40/40 [==============================] - 11s 273ms/step - loss: 0.0023 - categorical_accuracy: 0.9802 - val_loss: 0.0022 - val_categorical_accuracy: 0.9820
# Epoch 31/50
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0020 - categorical_accuracy: 0.9847 - val_loss: 0.0020 - val_categorical_accuracy: 0.9871
# Epoch 32/50
# 40/40 [==============================] - 11s 271ms/step - loss: 0.0018 - categorical_accuracy: 0.9901 - val_loss: 0.0017 - val_categorical_accuracy: 0.9914
# Epoch 33/50
# 40/40 [==============================] - 11s 273ms/step - loss: 0.0016 - categorical_accuracy: 0.9922 - val_loss: 0.0015 - val_categorical_accuracy: 0.9920
# Epoch 34/50
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0014 - categorical_accuracy: 0.9933 - val_loss: 0.0013 - val_categorical_accuracy: 0.9933
# Epoch 35/50
# 40/40 [==============================] - 11s 283ms/step - loss: 0.0012 - categorical_accuracy: 0.9942 - val_loss: 0.0011 - val_categorical_accuracy: 0.9945
# Epoch 36/50
# 40/40 [==============================] - 11s 277ms/step - loss: 0.0010 - categorical_accuracy: 0.9947 - val_loss: 9.8588e-04 - val_categorical_accuracy: 0.9950
# Epoch 37/50
# 40/40 [==============================] - 11s 275ms/step - loss: 9.0194e-04 - categorical_accuracy: 0.9967 - val_loss: 8.6531e-04 - val_categorical_accuracy: 0.9986
# Epoch 38/50
# 40/40 [==============================] - 12s 303ms/step - loss: 7.9326e-04 - categorical_accuracy: 0.9994 - val_loss: 7.6194e-04 - val_categorical_accuracy: 0.9999
# Epoch 39/50
# 40/40 [==============================] - 11s 272ms/step - loss: 7.0020e-04 - categorical_accuracy: 0.9999 - val_loss: 6.7349e-04 - val_categorical_accuracy: 1.0000
# Epoch 40/50
# 40/40 [==============================] - 11s 274ms/step - loss: 6.2052e-04 - categorical_accuracy: 1.0000 - val_loss: 5.9784e-04 - val_categorical_accuracy: 1.0000
# Epoch 41/50
# 40/40 [==============================] - 11s 273ms/step - loss: 5.5217e-04 - categorical_accuracy: 1.0000 - val_loss: 5.3287e-04 - val_categorical_accuracy: 1.0000
# Epoch 42/50
# 40/40 [==============================] - 11s 277ms/step - loss: 4.9312e-04 - categorical_accuracy: 1.0000 - val_loss: 4.7679e-04 - val_categorical_accuracy: 1.0000
# Epoch 43/50
# 40/40 [==============================] - 11s 277ms/step - loss: 4.4257e-04 - categorical_accuracy: 1.0000 - val_loss: 4.2878e-04 - val_categorical_accuracy: 1.0000
# Epoch 44/50
# 40/40 [==============================] - 11s 273ms/step - loss: 3.9916e-04 - categorical_accuracy: 1.0000 - val_loss: 3.8776e-04 - val_categorical_accuracy: 1.0000
# Epoch 45/50
# 40/40 [==============================] - 11s 278ms/step - loss: 3.6184e-04 - categorical_accuracy: 1.0000 - val_loss: 3.5223e-04 - val_categorical_accuracy: 1.0000
# Epoch 46/50
# 40/40 [==============================] - 11s 275ms/step - loss: 3.2955e-04 - categorical_accuracy: 1.0000 - val_loss: 3.2154e-04 - val_categorical_accuracy: 1.0000
# Epoch 47/50
# 40/40 [==============================] - 11s 273ms/step - loss: 3.0160e-04 - categorical_accuracy: 1.0000 - val_loss: 2.9495e-04 - val_categorical_accuracy: 1.0000
# Epoch 48/50
# 40/40 [==============================] - 11s 274ms/step - loss: 2.7736e-04 - categorical_accuracy: 1.0000 - val_loss: 2.7180e-04 - val_categorical_accuracy: 1.0000
# Epoch 49/50
# 40/40 [==============================] - 12s 301ms/step - loss: 2.5618e-04 - categorical_accuracy: 1.0000 - val_loss: 2.5153e-04 - val_categorical_accuracy: 1.0000
# Epoch 50/50
# 40/40 [==============================] - 11s 274ms/step - loss: 2.3751e-04 - categorical_accuracy: 1.0000 - val_loss: 2.3357e-04 - val_categorical_accuracy: 1.0000
# 40/40 - 1s - loss: 2.2649e-04 - categorical_accuracy: 1.0000 - 799ms/epoch - 20ms/step
# categorical_accuracy: 100.00%
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>

# %% [markdown]
# I used the softmax activation function in the decode because of the classification problem and also i increased the epochs to 50 and the batch size to 256 double compared to previous.
#
# when i compared with the linear model the non linear model performed good and also it is too complicated with same number of neurons like linear model with LSTM the number of parameters are more.
